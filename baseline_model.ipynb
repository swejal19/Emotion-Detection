# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Load dataset
data = np.load("data/processed/emotion_dataset.npz")
X_gray_train = data["X_gray_train"]
y_train = data["y_train"]

print("✅ Dataset loaded. Shapes:")
print("X_gray_train:", X_gray_train.shape)
print("y_train:", y_train.shape)
# Out:
# ✅ Dataset loaded. Shapes:
# X_gray_train: (22967, 48, 48, 1)
# y_train: (22967,)

# %%
NUM_CLASSES = 7
INPUT_SHAPE = (48, 48, 1)

model = Sequential([
    Conv2D(16, (3,3), activation='relu', input_shape=INPUT_SHAPE),
    MaxPooling2D((2,2)),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(NUM_CLASSES, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# c:\Users\Acer\Desktop\infosys\Project\venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 21, 21, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3200)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       204,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 210,119 (820.78 KB)
#  Trainable params: 210,119 (820.78 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

NUM_CLASSES = 7  # angry, disgust, fear, happy, neutral, sad, surprise
INPUT_SHAPE = (48, 48, 1)  # grayscale

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=INPUT_SHAPE),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(NUM_CLASSES, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
print("✅ Baseline model created")
# Out:
# ✅ Baseline model created

# %%
#model training 
from sklearn.model_selection import train_test_split

# Split training into train/validation
X_train, X_val, y_train_split, y_val = train_test_split(
    X_gray_train, y_train, test_size=0.2, random_state=42, stratify=y_train
)

print("Train shape:", X_train.shape, "Validation shape:", X_val.shape)

# Train model
history = model.fit(
    X_train, y_train_split,
    validation_data=(X_val, y_val),
    epochs=30,            # start small, can increase later
    batch_size=64,
    verbose=1
)
# Out:
# Train shape: (18373, 48, 48, 1) Validation shape: (4594, 48, 48, 1)
# Epoch 1/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - accuracy: 0.3802 - loss: 1.5927 - val_accuracy: 0.4334 - val_loss: 1.4912
# Epoch 2/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.4249 - loss: 1.4930 - val_accuracy: 0.4530 - val_loss: 1.4124
# Epoch 3/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.4526 - loss: 1.4236 - val_accuracy: 0.4610 - val_loss: 1.3903
# Epoch 4/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.4734 - loss: 1.3742 - val_accuracy: 0.4767 - val_loss: 1.3628
# Epoch 5/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.4924 - loss: 1.3354 - val_accuracy: 0.4926 - val_loss: 1.3314
# Epoch 6/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.5079 - loss: 1.2906 - val_accuracy: 0.4935 - val_loss: 1.3201
# Epoch 7/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.5256 - loss: 1.2471 - val_accuracy: 0.5035 - val_loss: 1.3090
# Epoch 8/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.5397 - loss: 1.2012 - val_accuracy: 0.4985 - val_loss: 1.3017
# Epoch 9/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.5509 - loss: 1.1640 - val_accuracy: 0.4998 - val_loss: 1.3203
# Epoch 10/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.5627 - loss: 1.1255 - val_accuracy: 0.5044 - val_loss: 1.3174
# Epoch 11/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.5859 - loss: 1.0816 - val_accuracy: 0.5111 - val_loss: 1.3093
# Epoch 12/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.5951 - loss: 1.0478 - val_accuracy: 0.5050 - val_loss: 1.3320
# Epoch 13/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.6151 - loss: 0.9988 - val_accuracy: 0.5059 - val_loss: 1.3289
# Epoch 14/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.6266 - loss: 0.9650 - val_accuracy: 0.5131 - val_loss: 1.3402
# Epoch 15/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.6423 - loss: 0.9267 - val_accuracy: 0.5091 - val_loss: 1.3648
# Epoch 16/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.6524 - loss: 0.8921 - val_accuracy: 0.5139 - val_loss: 1.4052
# Epoch 17/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.6670 - loss: 0.8523 - val_accuracy: 0.5067 - val_loss: 1.4140
# Epoch 18/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.6833 - loss: 0.8172 - val_accuracy: 0.5135 - val_loss: 1.4596
# Epoch 19/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.6943 - loss: 0.7807 - val_accuracy: 0.5194 - val_loss: 1.4591
# Epoch 20/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.7039 - loss: 0.7564 - val_accuracy: 0.5135 - val_loss: 1.4754
# Epoch 21/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.7127 - loss: 0.7266 - val_accuracy: 0.5224 - val_loss: 1.5187
# Epoch 22/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.7257 - loss: 0.6952 - val_accuracy: 0.5163 - val_loss: 1.5798
# Epoch 23/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.7367 - loss: 0.6681 - val_accuracy: 0.5124 - val_loss: 1.6094
# Epoch 24/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.7424 - loss: 0.6455 - val_accuracy: 0.5157 - val_loss: 1.6239
# Epoch 25/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.7516 - loss: 0.6214 - val_accuracy: 0.5155 - val_loss: 1.7692
# Epoch 26/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7524 - loss: 0.6103 - val_accuracy: 0.5165 - val_loss: 1.7697
# Epoch 27/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7625 - loss: 0.5887 - val_accuracy: 0.5061 - val_loss: 1.7934
# Epoch 28/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7715 - loss: 0.5699 - val_accuracy: 0.5083 - val_loss: 1.7959
# Epoch 29/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7705 - loss: 0.5563 - val_accuracy: 0.5096 - val_loss: 1.9157
# Epoch 30/30
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7835 - loss: 0.5308 - val_accuracy: 0.5120 - val_loss: 1.9643

# %%
#CNN for facial emotion recognition.
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# CNN Architecture
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(48,48,1)),   # FER images are usually 48x48 grayscale
    BatchNormalization(),
    MaxPooling2D((2,2)),
    
    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    
    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')  # 7 emotions (angry, disgust, fear, happy, sad, surprise, neutral)
])

# Compile
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# c:\Users\Acer\Desktop\infosys\Project\venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 46, 46, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 21, 21, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 21, 21, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 356,743 (1.36 MB)
#  Trainable params: 356,295 (1.36 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
#to avoid overfitting and Saves the best weights to ml/best_emotion_model.h5

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Callbacks
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=8,        # stop if val_loss doesn't improve for 5 epochs
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "ml/best_emotion_model.h5",  # saved model path
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# Train the model
history = model.fit(
    X_train, y_train_split,
    validation_data=(X_val, y_val),
    epochs=50,           # can adjust
    batch_size=64,
    callbacks=[early_stop, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/50
# 287/288 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7177 - loss: 0.7208
# Epoch 1: val_accuracy improved from None to 0.51654, saving model to ml/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 18s 64ms/step - accuracy: 0.7162 - loss: 0.7258 - val_accuracy: 0.5165 - val_loss: 1.6769
# Epoch 2/50
# 287/288 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7299 - loss: 0.6976
# Epoch 2: val_accuracy improved from 0.51654 to 0.53592, saving model to ml/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 19s 64ms/step - accuracy: 0.7245 - loss: 0.7061 - val_accuracy: 0.5359 - val_loss: 1.5087
# Epoch 3/50
# 287/288 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7549 - loss: 0.6314
# Epoch 3: val_accuracy improved from 0.53592 to 0.54201, saving model to ml/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 18s 64ms/step - accuracy: 0.7490 - loss: 0.6538 - val_accuracy: 0.5420 - val_loss: 1.6823
# Epoch 4/50
# 287/288 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7621 - loss: 0.6096
# Epoch 4: val_accuracy did not improve from 0.54201
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 19s 64ms/step - accuracy: 0.7573 - loss: 0.6225 - val_accuracy: 0.5309 - val_loss: 1.6440
# Epoch 5/50
# 287/288 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7796 - loss: 0.5769
# Epoch 5: val_accuracy did not improve from 0.54201
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 18s 64ms/step - accuracy: 0.7735 - loss: 0.5930 - val_accuracy: 0.4950 - val_loss: 1.8881
# Epoch 6/50
# 287/288 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7898 - loss: 0.5450
# Epoch 6: val_accuracy improved from 0.54201 to 0.54223, saving model to ml/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 19s 67ms/step - accuracy: 0.7867 - loss: 0.5577 - val_accuracy: 0.5422 - val_loss: 1.7825
# Epoch 7/50
# 287/288 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7759 - loss: 0.5819
# Epoch 7: val_accuracy did not improve from 0.54223
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - accuracy: 0.7819 - loss: 0.5628 - val_accuracy: 0.5270 - val_loss: 1.7065
# Epoch 8/50
# 287/288 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8094 - loss: 0.4960
# Epoch 8: val_accuracy did not improve from 0.54223
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - accuracy: 0.8025 - loss: 0.5118 - val_accuracy: 0.5065 - val_loss: 1.9155
# Epoch 9/50
# 287/288 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8129 - loss: 0.4859
# Epoch 9: val_accuracy improved from 0.54223 to 0.54549, saving model to ml/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 18s 64ms/step - accuracy: 0.8095 - loss: 0.4975 - val_accuracy: 0.5455 - val_loss: 1.8129
# Epoch 10/50
# 287/288 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8264 - loss: 0.4478
# Epoch 10: val_accuracy did not improve from 0.54549
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 19s 67ms/step - accuracy: 0.8198 - loss: 0.4664 - val_accuracy: 0.5370 - val_loss: 1.8966
